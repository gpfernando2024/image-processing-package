# %%
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
image1 = io.read_image('C:/Bootcamps/DIO/imagem/autumn_florest.jpg')
image2 = io.read_image('C:/Bootcamps/DIO/imagem/green_florest.jpg')

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result_image = combination.transfer_histogram(image1,image2)
plot.plot_result(image1,image2,result_image)

# %%
transformation.resize_image(image1,1)
# Out:
# array([[[0.17254902, 0.0627451 , 0.04705882],
#         [0.19215686, 0.10196078, 0.07058824],
#         [0.1254902 , 0.0745098 , 0.01176471],
#         ...,
#         [0.18039216, 0.2       , 0.21568627],
#         [0.28235294, 0.2627451 , 0.29019608],
#         [0.22745098, 0.18823529, 0.21960784]],
#
#        [[0.17254902, 0.06666667, 0.02352941],
#         [0.16470588, 0.07843137, 0.02352941],
#         [0.15294118, 0.10980392, 0.03921569],
#         ...,
#         [0.02745098, 0.04313725, 0.05490196],
#         [0.03137255, 0.01176471, 0.02745098],
#         [0.08627451, 0.0627451 , 0.07843137]],
#
#        [[0.23921569, 0.1372549 , 0.03921569],
#         [0.17647059, 0.09803922, 0.        ],
#         [0.16862745, 0.1372549 , 0.04705882],
#         ...,
#         [0.        , 0.00392157, 0.        ],
#         [0.00392157, 0.        , 0.        ],
#         [0.03137255, 0.01568627, 0.01176471]],
#
#        ...,
#
#        [[0.66666667, 0.71764706, 0.64705882],
#         [0.38039216, 0.42352941, 0.36862745],
#         [0.57647059, 0.59215686, 0.58823529],
#         ...,
#         [0.50980392, 0.50980392, 0.37647059],
#         [0.23137255, 0.19215686, 0.15294118],
#         [0.24313725, 0.18039216, 0.18039216]],
#
#        [[0.81176471, 0.8627451 , 0.79607843],
#         [0.56470588, 0.61176471, 0.55686275],
#         [0.81568627, 0.83921569, 0.82352941],
#         ...,
#         [0.36862745, 0.35686275, 0.23529412],
#         [0.33333333, 0.28235294, 0.25098039],
#         [0.3372549 , 0.2627451 , 0.27058824]],
#
#        [[0.72156863, 0.77647059, 0.71764706],
#         [0.81176471, 0.85882353, 0.81176471],
#         [0.8627451 , 0.90196078, 0.87058824],
#         ...,
#         [0.58039216, 0.58039216, 0.47058824],
#         [0.26666667, 0.22745098, 0.19215686],
#         [0.23137255, 0.16862745, 0.18039216]]])
