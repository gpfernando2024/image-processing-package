# %%
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
image1 = io.read_image('C:/Bootcamps/DIO/imagem/Floresta02.jpg')
image2 = io.read_image('C:/Bootcamps/DIO/imagem/Floresta01.jpg')

# %%
plot.plot_image(image1)
plot.plot_image(image1)

# %%
result_image = combination.transfer_histogram(image2,image1)

# %%
transformation.resize_image(
